# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
sns.set()
data=pd.read_csv('1.01. Simple linear regression.csv')

# %%
data
# Out:
#      SAT   GPA
# 0   1714  2.40
# 1   1664  2.52
# 2   1760  2.54
# 3   1685  2.74
# 4   1693  2.83
# 5   1670  2.91
# 6   1764  3.00
# 7   1764  3.00
# 8   1792  3.01
# 9   1850  3.01
# 10  1735  3.02
# 11  1775  3.07
# 12  1735  3.08
# 13  1712  3.08
# 14  1773  3.12
# 15  1872  3.17
# 16  1755  3.17
# 17  1674  3.17
# 18  1842  3.17
# 19  1786  3.19
# 20  1761  3.19
# 21  1722  3.19
# 22  1663  3.20
# 23  1687  3.21
# 24  1974  3.24
# 25  1826  3.28
# 26  1787  3.28
# 27  1821  3.28
# 28  2020  3.28
# 29  1794  3.28
# ..   ...   ...
# 54  1879  3.44
# 55  1887  3.47
# 56  1730  3.47
# 57  1953  3.47
# 58  1781  3.47
# 59  1891  3.48
# 60  1964  3.49
# 61  1808  3.49
# 62  1893  3.50
# 63  2041  3.51
# 64  1893  3.51
# 65  1832  3.52
# 66  1850  3.52
# 67  1934  3.54
# 68  1861  3.58
# 69  1931  3.58
# 70  1933  3.59
# 71  1778  3.59
# 72  1975  3.60
# 73  1934  3.60
# 74  2021  3.61
# 75  2015  3.62
# 76  1997  3.64
# 77  2020  3.65
# 78  1843  3.71
# 79  1936  3.71
# ...

# %%
data.describe()
# Out:
#                SAT        GPA
# count    84.000000  84.000000
# mean   1845.273810   3.330238
# std     104.530661   0.271617
# min    1634.000000   2.400000
# 25%    1772.000000   3.190000
# 50%    1846.000000   3.380000
# 75%    1934.000000   3.502500
# max    2050.000000   3.810000

# %%
# y=c+bx
y=data['GPA']
x=data['SAT']
plt.scatter(x,y)
plt.xlabel('SAT', fontsize=20)
plt.ylabel('GPA', fontsize=20)
plt.show()

# %%
x1=sm.add_constant(x)
results=sm.OLS(y,x1).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    GPA   R-squared:                       0.406
# Model:                            OLS   Adj. R-squared:                  0.399
# Method:                 Least Squares   F-statistic:                     56.05
# Date:                Tue, 08 Oct 2019   Prob (F-statistic):           7.20e-11
# Time:                        09:54:05   Log-Likelihood:                 12.672
# No. Observations:                  84   AIC:                            -21.34
# Df Residuals:                      82   BIC:                            -16.48
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2750      0.409      0.673      0.503      -0.538       1.088
# ...

# %%
plt.scatter(x,y)
yhat= x*0.0017+ 0.275 # constants are taken from summary 
fig=plt.plot(x,yhat, lw=4,c='orange',label='regression line')
plt.xlabel('SAT',fontsize=20)
plt.ylabel('GPA', fontsize=20)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn
seaborn.set()
data=pd.read_csv('real_estate_price_size.csv')

# %%
data
# Out:
#          price     size
# 0   234314.144   643.09
# 1   228581.528   656.22
# 2   281626.336   487.29
# 3   401255.608  1504.75
# 4   458674.256  1275.46
# 5   245050.280   575.19
# 6   265129.064   570.89
# 7   175716.480   620.82
# 8   331101.344   682.26
# 9   218630.608   694.52
# 10  279555.096  1060.36
# 11  494778.992  1842.51
# 12  215472.104   694.52
# 13  418753.008  1009.25
# 14  444192.008  1300.96
# 15  440201.616  1379.72
# 16  248337.600   690.54
# 17  234178.160   623.94
# 18  225451.984   681.07
# 19  299416.976  1027.76
# 20  268125.080   620.71
# 21  171795.240   549.69
# 22  412569.472  1207.45
# 23  183459.488   518.38
# 24  168047.264   525.81
# 25  362519.720  1103.30
# 26  271793.312   570.89
# 27  406852.304  1334.10
# 28  297760.440   681.07
# 29  368988.432  1496.36
# ..         ...      ...
# 70  276875.632  1021.95
# 71  181587.576   643.41
# 72  298926.496   656.22
# 73  211724.096   549.80
# 74  228313.024   685.48
# 75  286161.600   685.48
# ...

# %%
y=data['price']
x=data['size']
plt.scatter(x,y)
plt.xlabel('price', fontsize=20)
plt.ylabel('size', fontsize=20)
plt.show()

# %%
x1=sm.add_constant(x)
results=sm.OLS(y,x1).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.745
# Model:                            OLS   Adj. R-squared:                  0.742
# Method:                 Least Squares   F-statistic:                     285.9
# Date:                Tue, 08 Oct 2019   Prob (F-statistic):           8.13e-31
# Time:                        10:15:36   Log-Likelihood:                -1198.3
# No. Observations:                 100   AIC:                             2401.
# Df Residuals:                      98   BIC:                             2406.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.019e+05   1.19e+04      8.550      0.000    7.83e+04    1.26e+05
# ...

# %%
plt.scatter(x,y)
yhat=x*223.1787+1.019e+05 # constants are taken from summary 
fig=plt.plot(x,yhat, lw=4,c='orange',label='regression line')
plt.xlabel('price',fontsize=20)
plt.ylabel('size', fontsize=20)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.linear_model import LinearRegression
data=pd.read_csv('real_estate_price_size.csv')
data.head()
# Out:
#         price     size
# 0  234314.144   643.09
# 1  228581.528   656.22
# 2  281626.336   487.29
# 3  401255.608  1504.75
# 4  458674.256  1275.46

# %%
x=data['price']
y=data['size']
x.shape
y.shape
# Out:
# (100,)

# %%
reg=LinearRegression()
#reg.fit(x,y)
#x_matrix=x.values.reshape(1,-1) # reshape to size 2 from 100 or may use (100,1), or (-1,1) when one feature column only
x_matrix=x.values.reshape(-1,1)
reg.fit(x_matrix, y)
#reg.coef_
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
reg.score(x_matrix,y)
# Out:
# 0.7447391865847586

# %%
reg.intercept_
# Out:
# -122.33492122980181

# %%
reg.coef_
# Out:
# array([0.00333696])

# %%
reg.predict([[750]])  # used [[]] to overcome reshape errors
# Out:
# array([-119.83219905])

# %%
data.describe()
# Out:
#                price         size
# count     100.000000   100.000000
# mean   292289.470160   853.024200
# std     77051.727525   297.941951
# min    154282.128000   479.750000
# 25%    234280.148000   643.330000
# 50%    280590.716000   696.405000
# 75%    335723.696000  1029.322500
# max    500681.128000  1842.510000

# %%
reg.score(x_matrix,y)  #Rsquared
# Out:
# 0.7447391865847586

# %%
reg=LinearRegression()
#reg.fit(x,y)
x_matrix=x.values.reshape(-1, 1) # reshape to size 2 from 100 or may use (100,1)
reg.fit(x_matrix, y)
#reg.predict(750) #price predict for 750 sq ft size
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
